# %%
import streamlit as st
import pandas as pd
from PDP.twitter.twitterConstants import api_key, api_secrets, access_token, access_secret
from PDP.twitter.twitterScraper import authenticate, twitterScraper

def load_twitterScraper(api_key, api_secrets, access_token, access_secret):
    scraper = twitterScraper(api_key, api_secrets, access_token, access_secret)
    return scraper



scraper = load_twitterScraper(api_key, api_secrets, access_token, access_secret)
search = st.text_input(label='@add_twitter_account')

twitter_df = pd.DataFrame(columns=['name', 'tag', 'followers count', 'idols count'])
# Out:
# 2022-10-02 22:00:51.947
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /Users/tomzhang/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py [ARGUMENTS]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/streamlit/runtime/legacy_caching/hashing.py in to_bytes(self, obj, context)
#     367             # Hash the input
# --> 368             b = b"%s:%s" % (tname, self._to_bytes(obj, context))
#     369
#
# ~/opt/anaconda3/lib/python3.7/site-packages/streamlit/runtime/legacy_caching/hashing.py in _to_bytes(self, obj, context)
#     633             assert code is not None
# --> 634             if self._file_should_be_hashed(code.co_filename):
#     635                 context = _get_context(obj)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/streamlit/runtime/legacy_caching/hashing.py in _file_should_be_hashed(self, filename)
#     409         return file_util.file_is_in_folder_glob(
# --> 410             filepath, self._get_main_script_directory()
#     411         ) or file_util.file_in_pythonpath(filepath)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/streamlit/runtime/legacy_caching/hashing.py in _get_main_script_directory()
#     720         # script path in ScriptRunner.
# --> 721         abs_main_path = pathlib.Path(__main__.__file__).resolve()
#     722         return str(abs_main_path.parent)
#
# AttributeError: module '__main__' has no attribute '__file__'
#
# During handling of the above exception, another exception occurred:
#
# InternalHashError                         Traceback (most recent call last)
# <ipython-input-1-d8949079cbbf> in <module>
#      11
#      12
# ---> 13 scraper = load_twitterScraper(api_key, api_secrets, access_token, access_secret)
#      14 search = st.text_input(label='@add_twitter_account')
#      15
#
# ~/opt/anaconda3/lib/python3.7/site-packages/streamlit/runtime/legacy_caching/caching.py in wrapped_func(*args, **kwargs)
#     619         if show_spinner:
#     620             with st.spinner(message):
# --> 621                 return get_or_create_cached_value()
#     622         else:
#     623             return get_or_create_cached_value()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/streamlit/runtime/legacy_caching/caching.py in get_or_create_cached_value()
#     544                 # If we generated the key earlier we would only hash those
#     545                 # globals by name, and miss changes in their code or value.
# --> 546                 cache_key = _hash_func(non_optional_func, hash_funcs)
#     547
#     548             # First, get the cache that's attached to this function.
#
# ~/opt/anaconda3/lib/python3.7/site-packages/streamlit/runtime/legacy_caching/caching.py in _hash_func(func, hash_funcs)
#     675         hash_funcs=hash_funcs,
#     676         hash_reason=HashReason.CACHING_FUNC_BODY,
# --> 677         hash_source=func,
#     678     )
#     679     cache_key = func_hasher.hexdigest()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/streamlit/runtime/legacy_caching/hashing.py in update_hash(val, hasher, hash_reason, hash_source, context, hash_funcs)
#     114
#     115     ch = _CodeHasher(hash_funcs)
# --> 116     ch.update(hasher, val, context)
#     117
#     118
#
# ~/opt/anaconda3/lib/python3.7/site-packages/streamlit/runtime/legacy_caching/hashing.py in update(self, hasher, obj, context)
#     391     def update(self, hasher, obj: Any, context: Optional[Context] = None) -> None:
#     392         """Update the provided hasher with the hash of an object."""
# --> 393         b = self.to_bytes(obj, context)
#     394         hasher.update(b)
#     395
#
# ~/opt/anaconda3/lib/python3.7/site-packages/streamlit/runtime/legacy_caching/hashing.py in to_bytes(self, obj, context)
#     380
#     381         except BaseException as e:
# --> 382             raise InternalHashError(e, obj)
#     383
#     384         finally:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/streamlit/runtime/legacy_caching/hashing.py in to_bytes(self, obj, context)
#     366         try:
#     367             # Hash the input
# --> 368             b = b"%s:%s" % (tname, self._to_bytes(obj, context))
#     369
#     370             # Hmmm... It's possible that the size calculation is wrong. When we
#
# ~/opt/anaconda3/lib/python3.7/site-packages/streamlit/runtime/legacy_caching/hashing.py in _to_bytes(self, obj, context)
#     632             code = getattr(obj, "__code__", None)
#     633             assert code is not None
# --> 634             if self._file_should_be_hashed(code.co_filename):
#     635                 context = _get_context(obj)
#     636                 defaults = getattr(obj, "__defaults__", None)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/streamlit/runtime/legacy_caching/hashing.py in _file_should_be_hashed(self, filename)
#     408             return False
#     409         return file_util.file_is_in_folder_glob(
# --> 410             filepath, self._get_main_script_directory()
#     411         ) or file_util.file_in_pythonpath(filepath)
#     412
#
# ~/opt/anaconda3/lib/python3.7/site-packages/streamlit/runtime/legacy_caching/hashing.py in _get_main_script_directory()
#     719         # This works because we set __main__.__file__ to the
#     720         # script path in ScriptRunner.
# --> 721         abs_main_path = pathlib.Path(__main__.__file__).resolve()
#     722         return str(abs_main_path.parent)
#     723
#
# InternalHashError: module '__main__' has no attribute '__file__'
#
# While caching the body of `load_twitterScraper()`, Streamlit encountered an
# object of type `builtins.function`, which it does not know how to hash.
#
# **In this specific case, it's very likely you found a Streamlit bug so please
# [file a bug report here.]
# (https://github.com/streamlit/streamlit/issues/new/choose)**
#
# In the meantime, you can try bypassing this error by registering a custom
# hash function via the `hash_funcs` keyword in @st.cache(). For example:
#
# ```
# @st.cache(hash_funcs={builtins.function: my_hash_func})
# def my_func(...):
#     ...
# ```
#
# If you don't know where the object of type `builtins.function` is coming
# from, try looking at the hash chain below for an object that you do recognize,
# then pass that to `hash_funcs` instead:
#
# ```
# Object of type builtins.function: <function load_twitterScraper at 0x7febc52a4c20>
# ```
#
# Please see the `hash_funcs` [documentation]
# (https://docs.streamlit.io/library/advanced-features/caching#the-hash_funcs-parameter)
# for more details.
